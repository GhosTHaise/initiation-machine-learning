# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
X = np.array(['Chat','Chien','Chat','Oiseau'])

# %%
X
# Out:
# array(['Chat', 'Chien', 'Chat', 'Oiseau'], dtype='<U6')

# %%
transformer = LabelEncoder()
transformer.fit(X)
# Out:
# LabelEncoder()

# %%
transformer.transform(X)
# Out:
# array([0, 1, 0, 2])

# %%
transformer = LabelEncoder()
transformer.fit_transform(X)
# Out:
# array([0, 1, 0, 2], dtype=int64)

# %%
encoder = LabelEncoder()

# %%
train = np.array(["chat","chien","chat","oiseau","serpent"])

# %%
encoder.fit_transform(train)
# Out:
# array([0, 1, 0, 2, 3], dtype=int64)

# %%
encoder.inverse_transform(np.array([0,2,3,1,1,0,0]))
# Out:
# array(['chat', 'oiseau', 'serpent', 'chien', 'chien', 'chat', 'chat'],
#       dtype='<U7')

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X = np.array([["chat","poils"],
            ["chien","poils"],
            ["oiseau","plumes"],
            ["chat","poils"]])

# %%
encoder = OrdinalEncoder()
encoder.fit(X)
# Out:
# OrdinalEncoder()

# %%
encoder.transform(X)
# Out:
# array([[0., 1.],
#        [1., 1.],
#        [2., 0.],
#        [0., 1.]])

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
X = np.array(["chien","chat","chat","oiseau","chien"])

# %%
encoder = LabelBinarizer(sparse_output=True)
encoder.fit(X)
# Out:
# LabelBinarizer(sparse_output=True)

# %%
encoder.transform(X).toarray()
# Out:
# array([[0, 1, 0],
#        [1, 0, 0],
#        [1, 0, 0],
#        [0, 0, 1],
#        [0, 1, 0]])

# %%
print("---------------MinMaxScaler----------")
# Out:
# ---------------MinMaxScaler----------

# %%
from sklearn.preprocessing import MinMaxScaler , StandardScaler

# %%
X = np.array([[70],[80],[120]])

# %%
scaler = MinMaxScaler() 
scaler.fit_transform(X)
# Out:
# array([[0. ],
#        [0.2],
#        [1. ]])

# %%
scaler
# Out:
# MinMaxScaler()

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import numpy as np
iris = load_iris()

# %%
X = iris.data

outliers = np.full((10,4),100) + np.random.randn(10,4)
X = np.vstack((X,outliers))
print(outliers)

X_minmax = MinMaxScaler().fit_transform(X)
X_stdscl = StandardScaler().fit_transform(X)

plt.scatter(X[:,2],X[:,3],s=X_minmax[:,3],alpha=0.5,label="Normal")
plt.scatter(X_minmax[:,2],X_minmax[:,3],s=X_minmax[:,2],alpha=0.5,label="MinMaxScaler")
plt.scatter(X_stdscl[:,2],X_stdscl[:,3],s=X_stdscl[:,2],alpha=0.5,label="StandardScaler")

plt.legend()
plt.show()
# Out:
# [[100.09442184  98.94074264  99.55219438 100.02623646]
#  [100.93418851  99.52068776 100.78678454  99.51709867]
#  [ 99.86201021  99.83186068  99.85866179  99.81109867]
#  [ 99.16150937 101.16867132 100.31468633  98.75047361]
#  [100.48639825  98.66934739 101.79001404 100.26385963]
#  [ 99.87795557  98.40578044  99.90744096  98.41391638]
#  [ 99.61404026 102.69932406 100.18320855 100.89636326]
#  [100.54826705  99.97484079  98.70116268  99.70883472]
#  [100.1608734  100.77565086  99.01895918  99.8665767 ]
#  [100.05412456  99.00748838  98.73739314 100.17727214]]
# D:\Logiciel\Software\anaconda3\lib\site-packages\matplotlib\collections.py:981: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
# ...

# %%
print("----Polynomial Engeenering----")
# Out:
# ----Polynomial Engeenering----

# %%
from sklearn.preprocessing import PolynomialFeatures
x = np.array([[1],[2],[0.5]])

# %%
x
# Out:
# array([[1. ],
#        [2. ],
#        [0.5]])

# %%
PolynomialFeatures(2).fit_transform(x)
# Out:
# array([[1.  , 1.  , 1.  ],
#        [1.  , 2.  , 4.  ],
#        [1.  , 0.5 , 0.25]])

# %%
from sklearn.linear_model import LinearRegression
X = np.linspace(0,4,100).reshape((100,1))
y = X**2 + 5*np.cos(X) + np.random.randn(100,1)
x_poly = PolynomialFeatures(3).fit_transform(X)

plt.scatter(X,y)

model = LinearRegression().fit(x_poly,y)
y_pred = model.predict(x_poly)

plt.plot(X,y_pred,c='r',lw=3)
x_poly.shape
model.score(x_poly,y)
# Out:
# array([[ 4.63504651],
#        [ 4.6631831 ],
#        [ 4.68336772],
#        [ 4.69588464],
#        [ 4.7010181 ],
#        [ 4.69905235],
#        [ 4.69027166],
#        [ 4.67496028],
#        [ 4.65340245],
#        [ 4.62588244],
#        [ 4.59268451],
#        [ 4.55409289],
#        [ 4.51039186],
#        [ 4.46186565],
#        [ 4.40879854],
#        [ 4.35147476],
#        [ 4.29017858],
#        [ 4.22519426],
#        [ 4.15680603],
#        [ 4.08529817],
#        [ 4.01095492],
#        [ 3.93406053],
#        [ 3.85489927],
#        [ 3.77375539],
#        [ 3.69091313],
#        [ 3.60665676],
#        [ 3.52127053],
#        [ 3.4350387 ],
#        [ 3.34824551],
#        [ 3.26117522],
#        [ 3.17411209],
#        [ 3.08734038],
#        [ 3.00114432],
#        [ 2.91580819],
#        [ 2.83161624],
#        [ 2.74885271],
#        [ 2.66780186],
#        [ 2.58874795],
#        [ 2.51197524],
#        [ 2.43776796],
#        [ 2.36641039],
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target

x_train , x_test , y_train , y_test = train_test_split(x,y)

#tranform
scaler = StandardScaler()
x_train_transformed = scaler.fit_transform(x_train)

#estimateur
model = SGDClassifier(random_state=0)
model.fit(x_train_transformed,y_train)

#test
x_test_transformed = scaler.fit_transform(x_test)
print(model.predict(x_test_transformed),
      y_test,model.score(x_test_transformed,y_test))
# Out:
# [2 2 1 1 0 1 2 1 1 0 2 1 2 2 0 2 2 1 1 1 1 1 0 0 2 0 1 0 1 1 0 2 0 1 1 2 0
#  0] [2 2 1 1 0 1 2 1 1 0 2 1 2 2 1 2 2 2 1 1 1 1 0 0 2 0 1 0 1 1 0 2 0 1 2 2 1
#  0] 0.8947368421052632
